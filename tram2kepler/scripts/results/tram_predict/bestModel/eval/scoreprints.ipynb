# %%
import pandas as pd

# %%
def makeTable(s: pd.DataFrame, name):
    mask = (s['P'] == 0) & (s['R'] == 0) & (s['F1'] == 0)
    s = s[~mask]
    
    s = s.round(3)
    s = s.fillna('0')
    col = s['#'].apply(int).apply(str)
    s['#'] = col

    s_to_sort = s.iloc[:-2]
    s_to_keep = s.iloc[-2:]

    s = s_to_sort.sort_values(by=['Techniques'], ascending=False)

    s = pd.concat([s_to_sort, s_to_keep])


    print(s)
    s.to_latex(name + '.tex', index=False, escape=True, float_format="%.3f")

# %%
makeTable(pd.read_csv('tune_s.log'), 's')
makeTable(pd.read_csv('tune_s_aug.log'), 'sa')
makeTable(pd.read_csv('tune_m.csv'), 'm')
makeTable(pd.read_csv('tune_m_aug.log'), 'ma')
# Out:
#    Techniques      P      R     F1    #
# 0   T1003.001  0.926  1.000  0.962   25
# 1       T1005  0.700  0.538  0.609   13
# 3       T1016  1.000  0.706  0.828   17
# 4   T1021.001  0.769  1.000  0.870   20
# 5       T1027  0.923  0.876  0.899  137
# 6       T1033  1.000  0.222  0.364    9
# 7   T1036.005  0.867  0.650  0.743   20
# 8       T1041  0.833  0.417  0.556   12
# 9       T1047  0.786  0.917  0.846   12
# 10  T1053.005  1.000  0.952  0.976   21
# 11      T1055  0.923  0.980  0.950   49
# 12  T1056.001  1.000  1.000  1.000   11
# 13      T1057  0.941  0.941  0.941   17
# 14  T1059.003  0.805  0.984  0.886   63
# 15  T1070.004  0.889  0.667  0.762   12
# 16  T1071.001  0.806  0.967  0.879   30
# 19      T1078  0.833  0.921  0.875   38
# 20      T1082  0.750  0.828  0.787   29
# 21      T1083  0.636  0.737  0.683   19
# 22      T1090  0.875  0.840  0.857   25
# 23      T1095  1.000  0.571  0.727    7
# 24      T1105  0.612  0.925  0.737   53
# ...

# %%
makeTable(pd.read_csv('/Users/sougata/NMBU/Semester4/MyKEPLER/tram2kepler/scripts/results/tram_predict/dummyeval/eval_tram_dummy.log'), '/Users/sougata/NMBU/Semester4/MyKEPLER/tram2kepler/scripts/results/tram_predict/dummyeval/s')
makeTable(pd.read_csv('/Users/sougata/NMBU/Semester4/MyKEPLER/tram2kepler/scripts/results/tram_predict/dummyeval/eval_tram_dummy_m.log'), '/Users/sougata/NMBU/Semester4/MyKEPLER/tram2kepler/scripts/results/tram_predict/dummyeval/m')
makeTable(pd.read_csv('/Users/sougata/NMBU/Semester4/MyKEPLER/tram2kepler/scripts/results/tram_predict/trameval/eval_tram_s.log'), '/Users/sougata/NMBU/Semester4/MyKEPLER/tram2kepler/scripts/results/tram_predict/trameval/s')
makeTable(pd.read_csv('/Users/sougata/NMBU/Semester4/MyKEPLER/tram2kepler/scripts/results/tram_predict/trameval/eval_tram_m.log'), '/Users/sougata/NMBU/Semester4/MyKEPLER/tram2kepler/scripts/results/tram_predict/trameval/m')
# Out:
#    Techniques      P      R     F1   #
# 23      T1090  0.025  1.000  0.048  25
# 49    (micro)  0.025  0.025  0.025   0
# 50    (macro)  0.001  0.020  0.001   0
#    Techniques      P      R     F1   #
# 0       T1055  0.014  1.000  0.027  52
# 1       T1105  0.013  1.000  0.025  48
# 2       T1078  0.009  1.000  0.018  34
# 3   T1204.002  0.007  1.000  0.014  28
# 4   T1071.001  0.007  1.000  0.013  26
# 5       T1082  0.007  1.000  0.013  26
# 6   T1562.001  0.006  1.000  0.012  23
# 7       T1047  0.005  1.000  0.011  21
# 8   T1547.001  0.005  1.000  0.010  20
# 9   T1566.001  0.004  1.000  0.008  15
# 10  T1543.003  0.004  1.000  0.007  14
# 11  T1218.011  0.003  0.400  0.006  15
# 12  T1574.002  0.003  1.000  0.006  12
# 13      T1005  0.003  1.000  0.006  12
# 14      T1570  0.003  1.000  0.006  11
# 15      T1095  0.003  1.000  0.006  11
# 16      T1016  0.002  1.000  0.005   9
# 17      T1113  0.002  1.000  0.005   9
# 18      T1110  0.002  1.000  0.004   8
# ...
